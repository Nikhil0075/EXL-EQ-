# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib as plt
# %matplotlib inline

# %%
exl = pd.read_csv('EXL_EQ_2023_Dataset.csv',infer_datetime_format=True)

# %%
exl.head()
# Out:
#         PM2.5          NO         NO2         NOx        NH3        SO2  \
# 0  549.256878  181.010975   91.247522  188.364425  79.707417  10.175812
# 1  435.438303  194.247049   79.661701  203.481853  66.258913  11.615925
# 2  453.312378  112.499494  121.740909  153.914993  74.356791  10.590183
# 3  186.603123   56.922094  114.142207   91.504524        NaN  12.217971
# 4  262.616309   77.363086  123.790340  117.065760        NaN  13.331616
#
#          CO      Ozone   Benzene     Toluene  ...  \
# 0  3.520142  23.411029       NaN         NaN  ...
# 1  3.464807  29.331609  9.827428         NaN  ...
# 2  2.460498  30.172308  9.085975         NaN  ...
# 3  1.405930  30.493537  3.884649  104.475114  ...
# 4  2.692100  18.045684  5.605006   96.718827  ...
#
#    Installed Capacity of Power as of 2022(Megawatt)  \
# 0                                              7617
# 1                                              7617
# 2                                              7617
# ...

# %%
exl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223584 entries, 0 to 223583
# Data columns (total 45 columns):
#  #   Column                                            Non-Null Count   Dtype
# ---  ------                                            --------------   -----
#  0   PM2.5                                             218044 non-null  float64
#  1   NO                                                218735 non-null  float64
#  2   NO2                                               218244 non-null  float64
#  3   NOx                                               217612 non-null  float64
#  4   NH3                                               217948 non-null  float64
#  5   SO2                                               219700 non-null  float64
#  6   CO                                                219762 non-null  float64
#  7   Ozone                                             219154 non-null  float64
# ...

# %%
exl['City'].count()
# Out:
# 223584

# %%
exl.tail()
# Out:
#              PM2.5         NO        NO2         NOx         NH3        SO2  \
# 223579  196.989121  60.688939  88.463906  104.906711  109.511292  53.108086
# 223580  187.428487  56.707438  93.311216  103.099160  106.682026  55.535340
# 223581  176.635690  28.382382  87.318776   80.058537  110.258415  53.701056
# 223582  189.740021  12.664340  54.773063   51.766913   67.224030  40.155829
# 223583  164.385975  24.014566  66.402465   70.142974   94.957895  33.771574
#
#               CO      Ozone   Benzene   Toluene  ...  \
# 223579  2.336561  55.699203  3.684526  7.927572  ...
# 223580  2.235001  73.030945  3.388236  6.980251  ...
# 223581  1.754315  93.830288  3.328736  6.993954  ...
# 223582  1.361177  73.099207  2.423073  4.875033  ...
# 223583  1.770766  45.108456  2.719856  6.109795  ...
#
#         Installed Capacity of Power as of 2022(Megawatt)  \
# 223579                                             43446
# 223580                                             43446
# ...

# %%
exl.describe()
# Out:
#                PM2.5             NO            NO2            NOx  \
# count  218044.000000  218735.000000  218244.000000  217612.000000
# mean       69.213957      14.072135      30.366790      30.736544
# std        56.962718      22.097622      31.883841      31.688403
# min         0.100000       0.010000       0.010000       0.000000
# 25%        30.340937       4.006669      12.175122      13.329495
# 50%        51.630955       6.727626      19.174929      21.085326
# 75%        91.310000      13.334686      36.976778      35.779768
# max       890.873920     359.241357     300.479696     394.141771
#
#                  NH3            SO2             CO          Ozone  \
# count  217948.000000  219700.000000  219762.000000  219154.000000
# mean       26.234892      13.945535       0.987377      31.138962
# std        20.545715      10.851849       0.792493      21.908442
# min         0.100000       0.010000       0.000000       0.030000
# ...

# %%
exl.isnull()
# Out:
#         PM2.5     NO    NO2    NOx    NH3    SO2     CO  Ozone  Benzene  \
# 0       False  False  False  False  False  False  False  False     True
# 1       False  False  False  False  False  False  False  False    False
# 2       False  False  False  False  False  False  False  False    False
# 3       False  False  False  False   True  False  False  False    False
# 4       False  False  False  False   True  False  False  False    False
# ...       ...    ...    ...    ...    ...    ...    ...    ...      ...
# 223579  False  False  False  False  False  False  False  False    False
# 223580  False  False  False  False  False  False  False  False    False
# 223581  False  False  False  False  False  False  False  False    False
# 223582  False  False  False  False  False  False  False  False    False
# 223583  False  False  False  False  False  False  False  False    False
#
#         Toluene  ...  Installed Capacity of Power as of 2022(Megawatt)  \
# ...

# %%
sns.heatmap(exl.isnull(),yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(exl.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.set_style('whitegrid')

# %%
exl_delhi = exl.loc[exl['City'] == 'Delhi']

# %%
exl_delhi
# Out:
#            PM2.5          NO         NO2         NOx        NH3        SO2  \
# 0     549.256878  181.010975   91.247522  188.364425  79.707417  10.175812
# 1     435.438303  194.247049   79.661701  203.481853  66.258913  11.615925
# 2     453.312378  112.499494  121.740909  153.914993  74.356791  10.590183
# 3     186.603123   56.922094  114.142207   91.504524        NaN  12.217971
# 4     262.616309   77.363086  123.790340  117.065760        NaN  13.331616
# ...          ...         ...         ...         ...        ...        ...
# 6571  196.175491   52.489249   44.330505   45.859306  54.634551   9.123839
# 6572  116.911632   44.449446   47.760942   35.195136  60.027847  11.825594
# 6573   90.348195   44.880417   39.679084   29.945022  61.151805  11.122274
# 6574  128.424548   59.451189   55.696476   52.401969  63.372069  12.646547
# 6575  163.290713   70.097090   56.231357   64.130862  56.242020  13.827596
#
#             CO      Ozone   Benzene     Toluene  ...  \
# ...

# %%
sns.heatmap(exl_delhi.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.displot(exl_delhi['Temp'].dropna(),bins=30)

# %%
#sns.countplot(x='PM2.5',data=exl_delhi)
exl_delhi['PM2.5'].hist(bins=30,figsize=(10,4))
# Out:
# <AxesSubplot:>

# %%
#sns.boxplot(x='PM2.5',y='Temp',data=exl_delhi)

# %%
exl_delhi.drop(['Eth-Benzene','Xylene','MP-Xylene','O Xylene','CH4'],axis=1,inplace=True)
# Out:
# C:\Users\ROG\AppData\Local\Temp\ipykernel_15008\4042597342.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exl_delhi.drop(['Eth-Benzene','Xylene','MP-Xylene','O Xylene','CH4'],axis=1,inplace=True)

# %%
exl_delhi.head()
# Out:
#         PM2.5          NO         NO2         NOx        NH3        SO2  \
# 0  549.256878  181.010975   91.247522  188.364425  79.707417  10.175812
# 1  435.438303  194.247049   79.661701  203.481853  66.258913  11.615925
# 2  453.312378  112.499494  121.740909  153.914993  74.356791  10.590183
# 3  186.603123   56.922094  114.142207   91.504524        NaN  12.217971
# 4  262.616309   77.363086  123.790340  117.065760        NaN  13.331616
#
#          CO      Ozone   Benzene     Toluene  ...  \
# 0  3.520142  23.411029       NaN         NaN  ...
# 1  3.464807  29.331609  9.827428         NaN  ...
# 2  2.460498  30.172308  9.085975         NaN  ...
# 3  1.405930  30.493537  3.884649  104.475114  ...
# 4  2.692100  18.045684  5.605006   96.718827  ...
#
#    Installed Capacity of Power as of 2022(Megawatt)  \
# 0                                              7617
# 1                                              7617
# 2                                              7617
# ...

# %%
sns.heatmap(exl_delhi.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
exl_delhi['PM2.5'].count()
# Out:
# 6492

# %%
exl_delhi.drop(index=exl_delhi[exl_delhi['PM2.5'] == ' '].index)
# Out:
#            PM2.5          NO         NO2         NOx        NH3        SO2  \
# 0     549.256878  181.010975   91.247522  188.364425  79.707417  10.175812
# 1     435.438303  194.247049   79.661701  203.481853  66.258913  11.615925
# 2     453.312378  112.499494  121.740909  153.914993  74.356791  10.590183
# 3     186.603123   56.922094  114.142207   91.504524        NaN  12.217971
# 4     262.616309   77.363086  123.790340  117.065760        NaN  13.331616
# ...          ...         ...         ...         ...        ...        ...
# 6571  196.175491   52.489249   44.330505   45.859306  54.634551   9.123839
# 6572  116.911632   44.449446   47.760942   35.195136  60.027847  11.825594
# 6573   90.348195   44.880417   39.679084   29.945022  61.151805  11.122274
# 6574  128.424548   59.451189   55.696476   52.401969  63.372069  12.646547
# 6575  163.290713   70.097090   56.231357   64.130862  56.242020  13.827596
#
#             CO      Ozone   Benzene     Toluene  ...  \
# ...

# %%
sns.heatmap(exl_delhi.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.histplot(data=exl_delhi,x='PM2.5',y='Temp')
# Out:
# <AxesSubplot:xlabel='PM2.5', ylabel='Temp'>

# %%
sns.jointplot(x='PM2.5',y='Temp',data=exl_delhi,kind='kde')

# %%
#sns.pairplot(exl_delhi,hue='PM2.5')

# %%
exl_delhi['Temp']
# Out:
# 0        7.75
# 1        7.49
# 2        9.45
# 3       11.32
# 4       10.22
#         ...
# 6571    13.03
# 6572    13.91
# 6573    17.45
# 6574    15.34
# 6575    11.11
# Name: Temp, Length: 6576, dtype: float64

# %%
exl_delhi.loc[5]
# Out:
# PM2.5                                                     725.493847
# NO                                                               NaN
# NO2                                                              NaN
# NOx                                                              NaN
# NH3                                                              NaN
# SO2                                                        20.836571
# CO                                                          3.120651
# Ozone                                                      15.660919
# Benzene                                                          NaN
# Toluene                                                   181.840455
# Temp                                                            8.76
# RH                                                         89.073927
# WS                                                          0.220029
# WD                                                        185.221673
# ...

# %%
exl_delhi_1 = exl_delhi.iloc[:,:20]

# %%
exl_delhi_1
# Out:
#            PM2.5          NO         NO2         NOx        NH3        SO2  \
# 0     549.256878  181.010975   91.247522  188.364425  79.707417  10.175812
# 1     435.438303  194.247049   79.661701  203.481853  66.258913  11.615925
# 2     453.312378  112.499494  121.740909  153.914993  74.356791  10.590183
# 3     186.603123   56.922094  114.142207   91.504524        NaN  12.217971
# 4     262.616309   77.363086  123.790340  117.065760        NaN  13.331616
# ...          ...         ...         ...         ...        ...        ...
# 6571  196.175491   52.489249   44.330505   45.859306  54.634551   9.123839
# 6572  116.911632   44.449446   47.760942   35.195136  60.027847  11.825594
# 6573   90.348195   44.880417   39.679084   29.945022  61.151805  11.122274
# 6574  128.424548   59.451189   55.696476   52.401969  63.372069  12.646547
# 6575  163.290713   70.097090   56.231357   64.130862  56.242020  13.827596
#
# ...

# %%
#sns.pairplot(exl_delhi_1.iloc[:,:11],hue='PM2.5',kind='scatter')

# %%
##exl_delhi_1.columns()

# %%
exl_delhi_1.columns
# Out:
# Index(['PM2.5', 'NO', 'NO2', 'NOx', 'NH3', 'SO2', 'CO', 'Ozone', 'Benzene',
#        'Toluene', 'Temp', 'RH', 'WS', 'WD', 'SR', 'BP', 'AT', 'RF', 'TOT-RF',
#        'VWS'],
#       dtype='object')

# %%
sns.heatmap(exl_delhi_1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
exl_delhi_1['VWS'].value_counts()
# Out:
#  0.000000    60
#  0.010000    22
#  0.040000     7
#  0.030000     7
#  0.030000     5
#              ..
#  0.075885     1
#  0.072630     1
#  0.046226     1
#  0.015050     1
# -0.124884     1
# Name: VWS, Length: 5501, dtype: int64

# %%
exl_delhi_1['Toluene'].value_counts()
# Out:
# 104.475114    1
# 13.953207     1
# 33.031108     1
# 15.555801     1
# 15.702538     1
#              ..
# 27.120304     1
# 23.738122     1
# 24.544190     1
# 29.958989     1
# 22.843315     1
# Name: Toluene, Length: 5423, dtype: int64

# %%
exl_delhi_1['TOT-RF'].value_counts()
# Out:
# 0.000000    6282
# 1.108864       1
# 1.298958       1
# 4.841716       1
# 0.071648       1
#             ...
# 2.001284       1
# 0.796842       1
# 0.321113       1
# 2.152166       1
# 0.231377       1
# Name: TOT-RF, Length: 295, dtype: int64

# %%
exl_delhi_1['RF'].value_counts()
# Out:
# 0.000000    5235
# 5.488197       1
# 5.865834       1
# 5.512420       1
# 6.217019       1
#             ...
# 4.448794       1
# 5.117179       1
# 3.737753       1
# 3.707074       1
# 6.216307       1
# Name: RF, Length: 1124, dtype: int64

# %%
sns.jointplot(x='RF',y='TOT-RF',data=exl_delhi_1)

# %%
exl_delhi['PETROL'].value_counts()
# Out:
# 3,60,440    2196
# 3,64,886    2190
# 4,51,039    2190
# Name: PETROL, dtype: int64

# %%
exl['Time Periods'] = pd.to_datetime(exl['Time Periods'])

# %%
exl.head()
# Out:
#         PM2.5          NO         NO2         NOx        NH3        SO2  \
# 0  549.256878  181.010975   91.247522  188.364425  79.707417  10.175812
# 1  435.438303  194.247049   79.661701  203.481853  66.258913  11.615925
# 2  453.312378  112.499494  121.740909  153.914993  74.356791  10.590183
# 3  186.603123   56.922094  114.142207   91.504524        NaN  12.217971
# 4  262.616309   77.363086  123.790340  117.065760        NaN  13.331616
#
#          CO      Ozone   Benzene     Toluene  ...  \
# 0  3.520142  23.411029       NaN         NaN  ...
# 1  3.464807  29.331609  9.827428         NaN  ...
# 2  2.460498  30.172308  9.085975         NaN  ...
# 3  1.405930  30.493537  3.884649  104.475114  ...
# 4  2.692100  18.045684  5.605006   96.718827  ...
#
#    Installed Capacity of Power as of 2022(Megawatt)  \
# 0                                              7617
# 1                                              7617
# 2                                              7617
# ...

# %%
exl['Time Periods'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 223584 entries, 0 to 223583
# Series name: Time Periods
# Non-Null Count   Dtype
# --------------   -----
# 223584 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 1.7 MB

# %%
exl_delhi_1.describe()
# Out:
#              PM2.5           NO          NO2          NOx          NH3  \
# count  6492.000000  6373.000000  6457.000000  6449.000000  6207.000000
# mean    133.604348    46.634056    79.756541    61.565111    44.861745
# std      87.997770    42.913632    30.283065    49.729374    14.252056
# min      18.281461     4.397882    11.047893     5.440100    12.577865
# 25%      79.043667    18.498386    61.925755    25.770503    34.985342
# 50%      97.960259    31.052598    78.168082    45.441550    43.967773
# 75%     164.256041    57.409388    96.951637    79.468654    52.683053
# max     765.792213   305.307503   226.688342   330.423129   144.750028
#
#                SO2           CO        Ozone      Benzene      Toluene  \
# count  6433.000000  6462.000000  6469.000000  6444.000000  5423.000000
# mean     14.093319     1.413289    30.784631     2.900819    24.080195
# std       6.946540     0.779638    21.679737     2.104066    22.933754
# ...

# %%
exl_delhi_time = pd.to_datetime(exl_delhi.loc[:,'Time Periods'])

# %%
exl_delhi_time = exl_delhi['Time Periods']

# %%
exl_delhi_1.head()
# Out:
#         PM2.5          NO         NO2         NOx        NH3        SO2  \
# 0  549.256878  181.010975   91.247522  188.364425  79.707417  10.175812
# 1  435.438303  194.247049   79.661701  203.481853  66.258913  11.615925
# 2  453.312378  112.499494  121.740909  153.914993  74.356791  10.590183
# 3  186.603123   56.922094  114.142207   91.504524        NaN  12.217971
# 4  262.616309   77.363086  123.790340  117.065760        NaN  13.331616
#
#          CO      Ozone   Benzene     Toluene   Temp         RH        WS  \
# 0  3.520142  23.411029       NaN         NaN   7.75  93.437813  0.253857
# 1  3.464807  29.331609  9.827428         NaN   7.49  95.270911  0.233245
# 2  2.460498  30.172308  9.085975         NaN   9.45  67.747391  0.805488
# 3  1.405930  30.493537  3.884649  104.475114  11.32  51.006233  1.160145
# 4  2.692100  18.045684  5.605006   96.718827  10.22  69.689844  0.374948
#
#            WD          SR          BP         AT   RF  TOT-RF       VWS
# ...

# %%
exl_delhi_1['Time'] = exl_delhi_time

# %%
exl_delhi_1.head()
# Out:
#         PM2.5          NO         NO2         NOx        NH3        SO2  \
# 0  549.256878  181.010975   91.247522  188.364425  79.707417  10.175812
# 1  435.438303  194.247049   79.661701  203.481853  66.258913  11.615925
# 2  453.312378  112.499494  121.740909  153.914993  74.356791  10.590183
# 3  186.603123   56.922094  114.142207   91.504524        NaN  12.217971
# 4  262.616309   77.363086  123.790340  117.065760        NaN  13.331616
#
#          CO      Ozone   Benzene     Toluene  ...         RH        WS  \
# 0  3.520142  23.411029       NaN         NaN  ...  93.437813  0.253857
# 1  3.464807  29.331609  9.827428         NaN  ...  95.270911  0.233245
# 2  2.460498  30.172308  9.085975         NaN  ...  67.747391  0.805488
# 3  1.405930  30.493537  3.884649  104.475114  ...  51.006233  1.160145
# 4  2.692100  18.045684  5.605006   96.718827  ...  69.689844  0.374948
#
#            WD          SR          BP         AT   RF  TOT-RF       VWS  \
# ...

# %%
exl_delhi_1.drop(['RF','TOT-RF'],axis = 1,inplace=True)

# %%
exl_delhi_1
# Out:
#            PM2.5          NO         NO2         NOx        NH3        SO2  \
# 0     549.256878  181.010975   91.247522  188.364425  79.707417  10.175812
# 1     435.438303  194.247049   79.661701  203.481853  66.258913  11.615925
# 2     453.312378  112.499494  121.740909  153.914993  74.356791  10.590183
# 3     186.603123   56.922094  114.142207   91.504524        NaN  12.217971
# 4     262.616309   77.363086  123.790340  117.065760        NaN  13.331616
# ...          ...         ...         ...         ...        ...        ...
# 6571  196.175491   52.489249   44.330505   45.859306  54.634551   9.123839
# 6572  116.911632   44.449446   47.760942   35.195136  60.027847  11.825594
# 6573   90.348195   44.880417   39.679084   29.945022  61.151805  11.122274
# 6574  128.424548   59.451189   55.696476   52.401969  63.372069  12.646547
# 6575  163.290713   70.097090   56.231357   64.130862  56.242020  13.827596
#
# ...

# %%
sns.heatmap(exl_delhi_1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
exl_delhi_1.isnull().sum()
# Out:
# PM2.5        84
# NO          203
# NO2         119
# NOx         127
# NH3         369
# SO2         143
# CO          114
# Ozone       107
# Benzene     132
# Toluene    1153
# Temp         27
# RH          596
# WS          609
# WD          641
# SR          913
# BP          619
# AT          580
# VWS         968
# Time          0
# dtype: int64

# %%
# !pip install pandas_visual_analysis
from pandas_visual_analysis import VisualAnalysis
VisualAnalysis(exl_delhi_1)

# %%
VisualAnalysis(exl_delhi_1)

# %%
exl_delhi_1.corr()
# Out:
#             PM2.5        NO       NO2       NOx       NH3       SO2        CO  \
# PM2.5    1.000000  0.588809  0.478947  0.661123  0.591166  0.233341  0.675412
# NO       0.588809  1.000000  0.399322  0.955355  0.417155  0.235113  0.717175
# NO2      0.478947  0.399322  1.000000  0.451568  0.139425  0.111675  0.394248
# NOx      0.661123  0.955355  0.451568  1.000000  0.503439  0.324272  0.802890
# NH3      0.591166  0.417155  0.139425  0.503439  1.000000  0.223738  0.561524
# SO2      0.233341  0.235113  0.111675  0.324272  0.223738  1.000000  0.295879
# CO       0.675412  0.717175  0.394248  0.802890  0.561524  0.295879  1.000000
# Ozone   -0.252645 -0.394117 -0.303678 -0.340503 -0.133418  0.096358 -0.274094
# Benzene  0.741800  0.674359  0.442576  0.750796  0.542773  0.288585  0.761886
# Toluene  0.590497  0.658050  0.417848  0.710761  0.389646  0.211620  0.693158
# Temp    -0.604041 -0.494705 -0.386078 -0.501015 -0.454143 -0.007384 -0.475308
# ...

# %%
plt.pyplot.figure(figsize=(40,40))
sns.heatmap(exl_delhi_1[exl_delhi_1.corr().index].corr(),annot=True,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
#sns.jointplot(x='AT',y='Temp',data=exl_delhi_1,kind='kde')

# %%
exl_delhi_1.nunique()
# Out:
# PM2.5      6492
# NO         6373
# NO2        6457
# NOx        6449
# NH3        6207
# SO2        6433
# CO         6462
# Ozone      6469
# Benzene    6444
# Toluene    5423
# Temp       3001
# RH         5980
# WS         5967
# WD         5935
# SR         5663
# BP         5957
# AT         5996
# VWS        5501
# Time       6576
# dtype: int64

# %%
exl['City'].value_counts()
# Out:
# Delhi                 6576
# Kolkata               6576
# Agartala              6576
# Gaya                  6576
# Muzaffarpur           6576
# Patna                 6576
# Srinagar              6576
# Howrah                6576
# Bhopal                6576
# Ahmedabad             6576
# Gwalior               6576
# Bengaluru             6576
# Raipur                6576
# Bhilai                6576
# Chandigarh            6576
# Chennai               6576
# Thiruvananthapuram    6576
# Imphal                6576
# Kota                  6576
# Jaipur                6576
# Gurugram              6576
# Faridabad             6576
# Guwahati              6576
# Moradabad             6576
# Kanpur                6576
# Noida                 6576
# Agra                  6576
# Ghaziabad             6576
# Prayagraj             6576
# Meerut                6576
# Varanasi              6576
# Lucknow               6576
# Gandhinagar           6576
# Mumbai                6576
# ...

# %%
plt.pyplot.xticks(rotation=90)
sns.barplot(x='City',y='PM2.5',data=exl)
# Out:
# <AxesSubplot:xlabel='City', ylabel='PM2.5'>

# %%
plt.pyplot.figure(figsize=(30,10))
plt.pyplot.xticks(rotation=90)
exl.City.hist(bins=35)
# Out:
# <AxesSubplot:>

# %%
exl.isnull().sum()
# Out:
# PM2.5                                                 5540
# NO                                                    4849
# NO2                                                   5340
# NOx                                                   5972
# NH3                                                   5636
# SO2                                                   3884
# CO                                                    3822
# Ozone                                                 4430
# Benzene                                               6097
# Toluene                                              56554
# Temp                                                172116
# RH                                                   27211
# WS                                                    7080
# WD                                                    5809
# SR                                                   16383
# BP                                                   64451
# ...

# %%
exl['Temp'].isnull().sum()
# Out:
# 172116

# %%
exl.shape
# Out:
# (223584, 45)

# %%
nullvalues = exl.isnull().sum().sort_values(ascending=False)
null_value_percentage = (exl.isnull().sum()/exl.isnull().count()*100).sort_values(ascending=False)
missing_data = pd.concat([nullvalues,null_value_percentage],axis=1,keys=['Total','%'])
missing_data
# Out:
#                                                    Total          %
# CH4                                               217008  97.058824
# VWS                                               179561  80.310308
# Temp                                              172116  76.980464
# O Xylene                                          100446  44.925397
# Xylene                                             85753  38.353818
# BP                                                 64451  28.826302
# Toluene                                            56554  25.294297
# MP-Xylene                                          49322  22.059718
# Eth-Benzene                                        44297  19.812241
# RH                                                 27211  12.170370
# AT                                                 21570   9.647381
# SR                                                 16383   7.327447
# CNG ONLY                                           13152   5.882353
# ...

# %%
#sns.jointplot(x='AT',y='Temp',data=exl,kind='kde')

# %%
plt.pyplot.figure(figsize=(40,40))
sns.heatmap(exl[exl.corr().index].corr(),annot=True,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
VisualAnalysis(exl)

# %%
exl['CNG ONLY'].isnull().sum()

# %%
VisualAnalysis(exl)
